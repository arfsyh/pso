# %%
from main import PSOxBackpro
from random import random
import pandas as pd
from matplotlib import pyplot as plt

# %%
dataset = pd.read_csv('OPTIMASI.csv')
dataset_value = dataset.iloc[:, 8].values

# %%
normalized_dataset = list()

# %%
pd.DataFrame(dataset)
# Out:
#       ID Generator  Status      Result Status Proxy Role Keep SR2  Has SR2  \
# 0      0     Reuse  Reused  NormalTermination     Ignore      Yes     True
# 1      1     Reuse  Reused  NormalTermination   Training     Auto    False
# 2      2     Reuse  Reused  NormalTermination   Training     Auto    False
# 3      3     Reuse  Reused  NormalTermination   Training     Auto    False
# 4      4     Reuse  Reused  NormalTermination   Training     Auto    False
# 5      5     Reuse  Reused  NormalTermination   Training     Auto    False
# 6      6     Reuse  Reused  NormalTermination   Training     Auto    False
# 7      7     Reuse  Reused  NormalTermination   Training     Auto    False
# 8      8     Reuse  Reused  NormalTermination   Training     Auto    False
# 9      9     Reuse  Reused  NormalTermination   Training     Auto    False
# 10    10     Reuse  Reused  NormalTermination   Training     Auto    False
# 11    11     Reuse  Reused  NormalTermination   Training     Auto    False
# 12    12     Reuse  Reused  NormalTermination   Training     Auto    False
# 13    13     Reuse  Reused  NormalTermination   Training     Auto    False
# 14    14     Reuse  Reused  NormalTermination   Training     Auto    False
# 15    15     Reuse  Reused  NormalTermination   Training     Auto    False
# 16    16     Reuse  Reused  NormalTermination   Training     Auto    False
# 17    17     Reuse  Reused  NormalTermination   Training     Auto    False
# 18    18     Reuse  Reused  NormalTermination   Training     Auto    False
# 19    19     Reuse  Reused  NormalTermination   Training     Auto    False
# 20    20     Reuse  Reused  NormalTermination   Training     Auto    False
# 21    21     Reuse  Reused  NormalTermination   Training     Auto    False
# 22    22     Reuse  Reused  NormalTermination   Training     Auto    False
# 23    23     Reuse  Reused  NormalTermination   Training     Auto    False
# 24    24     Reuse  Reused  NormalTermination   Training     Auto    False
# 25    25     Reuse  Reused  NormalTermination   Training     Auto    False
# 26    26     Reuse  Reused  NormalTermination   Training     Auto    False
# 27    27     Reuse  Reused  NormalTermination   Training     Auto    False
# 28    28     Reuse  Reused  NormalTermination   Training     Auto    False
# 29    29     Reuse  Reused  NormalTermination   Training     Auto    False
# ..   ...       ...     ...                ...        ...      ...      ...
# 89    89     Reuse  Reused  NormalTermination   Training     Auto    False
# 90    90     Reuse  Reused  NormalTermination   Training     Auto    False
# 91    91     Reuse  Reused  NormalTermination   Training     Auto    False
# 92    92     Reuse  Reused  NormalTermination   Training     Auto    False
# 93    93     Reuse  Reused  NormalTermination   Training     Auto    False
# 94    94     Reuse  Reused  NormalTermination   Training     Auto    False
# 95    95     Reuse  Reused  NormalTermination   Training     Auto    False
# 96    96     Reuse  Reused  NormalTermination   Training     Auto    False
# 97    97     Reuse  Reused  NormalTermination   Training     Auto    False
# 98    98     Reuse  Reused  NormalTermination   Training     Auto    False
# 99    99     Reuse  Reused  NormalTermination   Training     Auto    False
# 100  100     Reuse  Reused  NormalTermination   Training     Auto    False
# 101  101     Reuse  Reused  NormalTermination   Training     Auto    False
# 102  102     Reuse  Reused  NormalTermination   Training     Auto    False
# 103  103     Reuse  Reused  NormalTermination   Training     Auto    False
# 104  104     Reuse  Reused  NormalTermination   Training     Auto    False
# 105  105     Reuse  Reused  NormalTermination   Training     Auto    False
# 106  106     Reuse  Reused  NormalTermination   Training     Auto    False
# 107  107     Reuse  Reused  NormalTermination   Training     Auto    False
# 108  108     Reuse  Reused  NormalTermination   Training     Auto    False
# 109  109     Reuse  Reused  NormalTermination   Training     Auto    False
# 110  110     Reuse  Reused  NormalTermination   Training     Auto    False
# 111  111     Reuse  Reused  NormalTermination   Training     Auto    False
# 112  112     Reuse  Reused  NormalTermination   Training     Auto    False
# 113  113     Reuse  Reused  NormalTermination   Training     Auto    False
# 114  114     Reuse  Reused  NormalTermination   Training     Auto    False
# 115  115     Reuse  Reused  NormalTermination   Training     Auto    False
# 116  116     Reuse  Reused  NormalTermination   Training     Auto    False
# 117  117     Reuse  Reused  NormalTermination   Training     Auto    False
# 118  118     Reuse  Reused  NormalTermination   Training     Auto    False
#
#      Highlight  InjectorPinjw  InjectorQual  InjectorStw  InjectorTinjw  \
# 0        False          500.0          0.90       1000.0          450.0
# 1        False          650.0          0.50       1050.0          300.0
# 2        False          510.0          0.85       1000.0          480.0
# 3        False          580.0          0.75        950.0          360.0
# 4        False          545.0          0.40       1250.0          420.0
# 5        False          440.0          0.50        950.0          510.0
# 6        False          405.0          0.40       1050.0          480.0
# 7        False          405.0          0.80       1100.0          450.0
# 8        False          650.0          0.40       1200.0          330.0
# 9        False          615.0          0.50        750.0          540.0
# 10       False          335.0          0.75       1250.0          420.0
# 11       False          300.0          0.65       1250.0          480.0
# 12       False          300.0          0.85       1100.0          510.0
# 13       False          370.0          0.75       1150.0          420.0
# 14       False          405.0          0.75       1150.0          600.0
# 15       False          475.0          0.70       1000.0          540.0
# 16       False          545.0          0.45       1150.0          450.0
# 17       False          545.0          0.90       1200.0          390.0
# 18       False          615.0          0.60       1000.0          330.0
# 19       False          510.0          0.40        950.0          360.0
# 20       False          510.0          0.90       1200.0          510.0
# 21       False          475.0          0.80       1150.0          600.0
# 22       False          580.0          0.60        750.0          360.0
# 23       False          580.0          0.55       1200.0          480.0
# 24       False          615.0          0.60        750.0          510.0
# 25       False          405.0          0.40        800.0          420.0
# 26       False          510.0          0.55       1050.0          300.0
# 27       False          615.0          0.45        900.0          300.0
# 28       False          440.0          0.50        900.0          450.0
# 29       False          300.0          0.45       1050.0          600.0
# ..         ...            ...           ...          ...            ...
# 89       False          335.0          0.85        800.0          510.0
# 90       False          650.0          0.85       1050.0          360.0
# 91       False          510.0          0.55       1200.0          300.0
# 92       False          475.0          0.80       1100.0          420.0
# 93       False          370.0          0.60        800.0          390.0
# 94       False          510.0          0.70        850.0          420.0
# 95       False          370.0          0.55       1250.0          330.0
# 96       False          405.0          0.80       1000.0          360.0
# 97       False          440.0          0.40        950.0          570.0
# 98       False          650.0          0.70        850.0          540.0
# 99       False          580.0          0.75       1050.0          300.0
# 100      False          405.0          0.80        850.0          360.0
# 101      False          335.0          0.50        750.0          360.0
# 102      False          545.0          0.60        950.0          450.0
# 103      False          370.0          0.65        950.0          540.0
# 104      False          650.0          0.55       1150.0          450.0
# 105      False          405.0          0.45        750.0          420.0
# 106      False          580.0          0.85        750.0          570.0
# 107      False          335.0          0.75       1150.0          300.0
# 108      False          545.0          0.50        800.0          600.0
# 109      False          405.0          0.45        950.0          390.0
# 110      False          440.0          0.70        750.0          390.0
# 111      False          475.0          0.60       1150.0          540.0
# 112      False          440.0          0.60       1250.0          300.0
# 113      False          370.0          0.45       1000.0          540.0
# 114      False          475.0          0.50       1200.0          510.0
# 115      False          335.0          0.50        900.0          510.0
# 116      False          580.0          0.50       1150.0          390.0
# 117      False          650.0          0.85       1000.0          540.0
# 118      False          650.0          0.70        900.0          570.0
#
#             RF       SOR   Execution Node  \
# 0    16.392569  3.293050              NaN
# 1    16.305593  4.107182  DESKTOP-V31NM3G
# 2    16.464912  3.151557  DESKTOP-V31NM3G
# 3    15.951070  3.096711  DESKTOP-V31NM3G
# 4    16.951200  4.404405  DESKTOP-V31NM3G
# 5    16.145294  3.492895  DESKTOP-V31NM3G
# 6    16.417343  3.954438  DESKTOP-V31NM3G
# 7    16.641983  3.140106  DESKTOP-V31NM3G
# 8    16.797417  4.732507  DESKTOP-V31NM3G
# 9    15.139260  3.141408  DESKTOP-V31NM3G
# 10   16.833309  3.251646  DESKTOP-V31NM3G
# 11   17.030699  3.466386  DESKTOP-V31NM3G
# 12   16.872293  3.242170  DESKTOP-V31NM3G
# 13   16.660080  3.237014  DESKTOP-V31NM3G
# 14   17.213617  3.280000  DESKTOP-V31NM3G
# 15   16.591919  3.202008  DESKTOP-V31NM3G
# 16   16.738144  3.941910  DESKTOP-V31NM3G
# 17   16.822392  3.196087  DESKTOP-V31NM3G
# 18   16.093348  3.544657  DESKTOP-V31NM3G
# 19   15.860038  4.169310  DESKTOP-V31NM3G
# 20   17.245975  3.376546  DESKTOP-V31NM3G
# 21   17.239626  3.295934  DESKTOP-V31NM3G
# 22   14.892118  3.133624  DESKTOP-V31NM3G
# 23   16.917780  3.638173  DESKTOP-V31NM3G
# 24   15.120241  3.019618  DESKTOP-V31NM3G
# 25   15.141191  3.671481  DESKTOP-V31NM3G
# 26   16.299093  3.870094  DESKTOP-V31NM3G
# 27   15.593158  4.037754  DESKTOP-V31NM3G
# 28   15.781152  3.483654  DESKTOP-V31NM3G
# 29   16.684200  3.584167  DESKTOP-V31NM3G
# ..         ...       ...              ...
# 89   15.543313  2.794709  DESKTOP-V31NM3G
# 90   16.381088  3.139349  DESKTOP-V31NM3G
# 91   16.755146  4.032399  DESKTOP-V31NM3G
# 92   16.579655  3.135583  DESKTOP-V31NM3G
# 93   15.230950  3.167254  DESKTOP-V31NM3G
# 94   15.541563  2.998308  DESKTOP-V31NM3G
# 95   16.867113  3.984203  DESKTOP-V31NM3G
# 96   16.154448  3.071728  DESKTOP-V31NM3G
# 97   16.234453  3.620216  DESKTOP-V31NM3G
# 98   15.889997  3.004811  DESKTOP-V31NM3G
# 99   16.279984  3.228414  DESKTOP-V31NM3G
# 100  15.504210  2.894398  DESKTOP-V31NM3G
# 101  14.832744  3.379038  DESKTOP-V31NM3G
# 102  16.047485  3.351208  DESKTOP-V31NM3G
# 103  16.360538  3.205611  DESKTOP-V31NM3G
# 104  16.729961  3.669995  DESKTOP-V31NM3G
# 105  14.847908  3.404109  DESKTOP-V31NM3G
# 106  15.455182  2.755943  DESKTOP-V31NM3G
# 107  16.565737  3.335269  DESKTOP-V31NM3G
# 108  15.516507  3.179394  DESKTOP-V31NM3G
# 109  15.913246  3.865114  DESKTOP-V31NM3G
# 110  14.936904  2.890310  DESKTOP-V31NM3G
# 111  17.024702  3.453713  DESKTOP-V31NM3G
# 112  16.841238  3.857150  DESKTOP-V31NM3G
# 113  16.396444  3.632836  DESKTOP-V31NM3G
# 114  17.002661  3.742870  DESKTOP-V31NM3G
# 115  15.911530  3.425730  DESKTOP-V31NM3G
# 116  16.667269  3.918625  DESKTOP-V31NM3G
# 117  16.661501  3.190063  DESKTOP-V31NM3G
# 118  16.206450  3.074503  DESKTOP-V31NM3G
#
#                                  Dataset Path  Optimal  Comment
# 0                            CMGBuilder00.dat    False      NaN
# 1    September 11.cmsd\September 11_00001.dat    False      NaN
# 2    September 11.cmsd\September 11_00002.dat    False      NaN
# 3    September 11.cmsd\September 11_00003.dat    False      NaN
# 4    September 11.cmsd\September 11_00004.dat    False      NaN
# 5    September 11.cmsd\September 11_00005.dat    False      NaN
# 6    September 11.cmsd\September 11_00006.dat    False      NaN
# 7    September 11.cmsd\September 11_00007.dat    False      NaN
# 8    September 11.cmsd\September 11_00008.dat    False      NaN
# 9    September 11.cmsd\September 11_00009.dat    False      NaN
# 10   September 11.cmsd\September 11_00010.dat    False      NaN
# 11   September 11.cmsd\September 11_00011.dat    False      NaN
# 12   September 11.cmsd\September 11_00012.dat    False      NaN
# 13   September 11.cmsd\September 11_00013.dat    False      NaN
# 14   September 11.cmsd\September 11_00014.dat    False      NaN
# 15   September 11.cmsd\September 11_00015.dat    False      NaN
# 16   September 11.cmsd\September 11_00016.dat    False      NaN
# 17   September 11.cmsd\September 11_00017.dat    False      NaN
# 18   September 11.cmsd\September 11_00018.dat    False      NaN
# 19   September 11.cmsd\September 11_00019.dat    False      NaN
# 20   September 11.cmsd\September 11_00020.dat    False      NaN
# 21   September 11.cmsd\September 11_00021.dat    False      NaN
# 22   September 11.cmsd\September 11_00022.dat    False      NaN
# 23   September 11.cmsd\September 11_00023.dat    False      NaN
# 24   September 11.cmsd\September 11_00024.dat    False      NaN
# 25   September 11.cmsd\September 11_00025.dat    False      NaN
# 26   September 11.cmsd\September 11_00026.dat    False      NaN
# 27   September 11.cmsd\September 11_00027.dat    False      NaN
# 28   September 11.cmsd\September 11_00028.dat    False      NaN
# 29   September 11.cmsd\September 11_00029.dat    False      NaN
# ..                                        ...      ...      ...
# 89   September 11.cmsd\September 11_00089.dat    False      NaN
# 90   September 11.cmsd\September 11_00090.dat    False      NaN
# 91   September 11.cmsd\September 11_00091.dat    False      NaN
# 92   September 11.cmsd\September 11_00092.dat    False      NaN
# 93   September 11.cmsd\September 11_00093.dat    False      NaN
# 94   September 11.cmsd\September 11_00094.dat    False      NaN
# 95   September 11.cmsd\September 11_00095.dat    False      NaN
# 96   September 11.cmsd\September 11_00096.dat    False      NaN
# 97   September 11.cmsd\September 11_00097.dat    False      NaN
# 98   September 11.cmsd\September 11_00098.dat    False      NaN
# 99   September 11.cmsd\September 11_00099.dat    False      NaN
# 100  September 11.cmsd\September 11_00100.dat    False      NaN
# 101  September 11.cmsd\September 11_00101.dat    False      NaN
# 102  September 11.cmsd\September 11_00102.dat    False      NaN
# 103  September 11.cmsd\September 11_00103.dat    False      NaN
# 104  September 11.cmsd\September 11_00104.dat    False      NaN
# 105  September 11.cmsd\September 11_00105.dat    False      NaN
# 106  September 11.cmsd\September 11_00106.dat    False      NaN
# 107  September 11.cmsd\September 11_00107.dat    False      NaN
# 108  September 11.cmsd\September 11_00108.dat    False      NaN
# 109  September 11.cmsd\September 11_00109.dat    False      NaN
# 110  September 11.cmsd\September 11_00110.dat    False      NaN
# 111  September 11.cmsd\September 11_00111.dat    False      NaN
# 112  September 11.cmsd\September 11_00112.dat    False      NaN
# 113  September 11.cmsd\September 11_00113.dat    False      NaN
# 114  September 11.cmsd\September 11_00114.dat    False      NaN
# 115  September 11.cmsd\September 11_00115.dat    False      NaN
# 116  September 11.cmsd\September 11_00116.dat    False      NaN
# 117  September 11.cmsd\September 11_00117.dat    False      NaN
# 118  September 11.cmsd\September 11_00118.dat    False      NaN
#
# [119 rows x 18 columns]

# %%
data = dataset[['InjectorPinjw','InjectorQual','InjectorStw','InjectorTinjw']].astype('str')

# %%
pd.DataFrame(data)
# Out:
#     InjectorPinjw InjectorQual InjectorStw InjectorTinjw
# 0           500.0          0.9      1000.0         450.0
# 1           650.0          0.5      1050.0         300.0
# 2           510.0         0.85      1000.0         480.0
# 3           580.0         0.75       950.0         360.0
# 4           545.0          0.4      1250.0         420.0
# 5           440.0          0.5       950.0         510.0
# 6           405.0          0.4      1050.0         480.0
# 7           405.0          0.8      1100.0         450.0
# 8           650.0          0.4      1200.0         330.0
# 9           615.0          0.5       750.0         540.0
# 10          335.0         0.75      1250.0         420.0
# 11          300.0         0.65      1250.0         480.0
# 12          300.0         0.85      1100.0         510.0
# 13          370.0         0.75      1150.0         420.0
# 14          405.0         0.75      1150.0         600.0
# 15          475.0          0.7      1000.0         540.0
# 16          545.0         0.45      1150.0         450.0
# 17          545.0          0.9      1200.0         390.0
# 18          615.0          0.6      1000.0         330.0
# 19          510.0          0.4       950.0         360.0
# 20          510.0          0.9      1200.0         510.0
# 21          475.0          0.8      1150.0         600.0
# 22          580.0          0.6       750.0         360.0
# 23          580.0         0.55      1200.0         480.0
# 24          615.0          0.6       750.0         510.0
# 25          405.0          0.4       800.0         420.0
# 26          510.0         0.55      1050.0         300.0
# 27          615.0         0.45       900.0         300.0
# 28          440.0          0.5       900.0         450.0
# 29          300.0         0.45      1050.0         600.0
# ..            ...          ...         ...           ...
# 89          335.0         0.85       800.0         510.0
# 90          650.0         0.85      1050.0         360.0
# 91          510.0         0.55      1200.0         300.0
# 92          475.0          0.8      1100.0         420.0
# 93          370.0          0.6       800.0         390.0
# 94          510.0          0.7       850.0         420.0
# 95          370.0         0.55      1250.0         330.0
# 96          405.0          0.8      1000.0         360.0
# 97          440.0          0.4       950.0         570.0
# 98          650.0          0.7       850.0         540.0
# 99          580.0         0.75      1050.0         300.0
# 100         405.0          0.8       850.0         360.0
# 101         335.0          0.5       750.0         360.0
# 102         545.0          0.6       950.0         450.0
# 103         370.0         0.65       950.0         540.0
# 104         650.0         0.55      1150.0         450.0
# 105         405.0         0.45       750.0         420.0
# 106         580.0         0.85       750.0         570.0
# 107         335.0         0.75      1150.0         300.0
# 108         545.0          0.5       800.0         600.0
# 109         405.0         0.45       950.0         390.0
# 110         440.0          0.7       750.0         390.0
# 111         475.0          0.6      1150.0         540.0
# 112         440.0          0.6      1250.0         300.0
# 113         370.0         0.45      1000.0         540.0
# 114         475.0          0.5      1200.0         510.0
# 115         335.0          0.5       900.0         510.0
# 116         580.0          0.5      1150.0         390.0
# 117         650.0         0.85      1000.0         540.0
# 118         650.0          0.7       900.0         570.0
#
# [119 rows x 4 columns]

# %%
normalized_dataset = list()
for x in range(len(dataset_value)):
    norm_value = (dataset_value[x] - min(dataset_value)) / (
        max(dataset_value) - min(dataset_value))
    normalized_dataset.append(norm_value)

optimasi_dataset = [
    normalized_dataset[:len(normalized_dataset) - 5],
    normalized_dataset[1:len(normalized_dataset) - 4],
    normalized_dataset[2:len(normalized_dataset) - 3],
    normalized_dataset[3:len(normalized_dataset) - 2],
    normalized_dataset[4:len(normalized_dataset) - 1],
    normalized_dataset[5:]]

print(pd.DataFrame([list(i) for i in zip(*optimasi_dataset)]))

df = pd.DataFrame([list(i) for i in zip(*optimasi_dataset)])


X_train = df.iloc[:, :5]
Y_train = df.iloc[:, 5]
X_test = df.iloc[:, :5]
Y_test = df.iloc[:, 5]

max_val = 1292.0
min_val = 538.0
# Out:
#             0    1    2    3    4    5
# 0    0.571429  1.0  0.6  0.8  0.7  0.4
# 1    1.000000  0.6  0.8  0.7  0.4  0.3
# 2    0.600000  0.8  0.7  0.4  0.3  0.3
# 3    0.800000  0.7  0.4  0.3  0.3  1.0
# 4    0.700000  0.4  0.3  0.3  1.0  0.9
# 5    0.400000  0.3  0.3  1.0  0.9  0.1
# 6    0.300000  0.3  1.0  0.9  0.1  0.0
# 7    0.300000  1.0  0.9  0.1  0.0  0.0
# 8    1.000000  0.9  0.1  0.0  0.0  0.2
# 9    0.900000  0.1  0.0  0.0  0.2  0.3
# 10   0.100000  0.0  0.0  0.2  0.3  0.5
# 11   0.000000  0.0  0.2  0.3  0.5  0.7
# 12   0.000000  0.2  0.3  0.5  0.7  0.7
# 13   0.200000  0.3  0.5  0.7  0.7  0.9
# 14   0.300000  0.5  0.7  0.7  0.9  0.6
# 15   0.500000  0.7  0.7  0.9  0.6  0.6
# 16   0.700000  0.7  0.9  0.6  0.6  0.5
# 17   0.700000  0.9  0.6  0.6  0.5  0.8
# 18   0.900000  0.6  0.6  0.5  0.8  0.8
# 19   0.600000  0.6  0.5  0.8  0.8  0.9
# 20   0.600000  0.5  0.8  0.8  0.9  0.3
# 21   0.500000  0.8  0.8  0.9  0.3  0.6
# 22   0.800000  0.8  0.9  0.3  0.6  0.9
# 23   0.800000  0.9  0.3  0.6  0.9  0.4
# 24   0.900000  0.3  0.6  0.9  0.4  0.0
# 25   0.300000  0.6  0.9  0.4  0.0  0.7
# 26   0.600000  0.9  0.4  0.0  0.7  0.0
# 27   0.900000  0.4  0.0  0.7  0.0  0.4
# 28   0.400000  0.0  0.7  0.0  0.4  0.5
# 29   0.000000  0.7  0.0  0.4  0.5  0.8
# ..        ...  ...  ...  ...  ...  ...
# 84   0.700000  0.5  0.7  0.3  0.9  0.1
# 85   0.500000  0.7  0.3  0.9  0.1  1.0
# 86   0.700000  0.3  0.9  0.1  1.0  0.6
# 87   0.300000  0.9  0.1  1.0  0.6  0.5
# 88   0.900000  0.1  1.0  0.6  0.5  0.2
# 89   0.100000  1.0  0.6  0.5  0.2  0.6
# 90   1.000000  0.6  0.5  0.2  0.6  0.2
# 91   0.600000  0.5  0.2  0.6  0.2  0.3
# 92   0.500000  0.2  0.6  0.2  0.3  0.4
# 93   0.200000  0.6  0.2  0.3  0.4  1.0
# 94   0.600000  0.2  0.3  0.4  1.0  0.8
# 95   0.200000  0.3  0.4  1.0  0.8  0.3
# 96   0.300000  0.4  1.0  0.8  0.3  0.1
# 97   0.400000  1.0  0.8  0.3  0.1  0.7
# 98   1.000000  0.8  0.3  0.1  0.7  0.2
# 99   0.800000  0.3  0.1  0.7  0.2  1.0
# 100  0.300000  0.1  0.7  0.2  1.0  0.3
# 101  0.100000  0.7  0.2  1.0  0.3  0.8
# 102  0.700000  0.2  1.0  0.3  0.8  0.1
# 103  0.200000  1.0  0.3  0.8  0.1  0.7
# 104  1.000000  0.3  0.8  0.1  0.7  0.3
# 105  0.300000  0.8  0.1  0.7  0.3  0.4
# 106  0.800000  0.1  0.7  0.3  0.4  0.5
# 107  0.100000  0.7  0.3  0.4  0.5  0.4
# 108  0.700000  0.3  0.4  0.5  0.4  0.2
# 109  0.300000  0.4  0.5  0.4  0.2  0.5
# 110  0.400000  0.5  0.4  0.2  0.5  0.1
# 111  0.500000  0.4  0.2  0.5  0.1  0.8
# 112  0.400000  0.2  0.5  0.1  0.8  1.0
# 113  0.200000  0.5  0.1  0.8  1.0  1.0
#
# [114 rows x 6 columns]

# %%
g_best_fitness = []
average_fitness = []

iter_param_test = [20, 40, 60, 80]
pso_backpp = PSOxBackpro(pop_size=10, particle_size=15, k=1)
pso_backpp.set_backpro_param(X_train, Y_train, X_test, Y_test, max_val, min_val, epoch=40)    
for iterasi in range(len(iter_param_test)):
    g_best_fitness_temp = 0
    average_fitness_temp = 0
    for i in range(5):
        print('.',end=' ')
        pso_backpp.initPops()
        gbest_fitness, avg_fitness = pso_backpp.optimize(
            iter_param_test[iterasi], 1, 1, 1)
        g_best_fitness_temp += gbest_fitness
        average_fitness_temp += avg_fitness
    print(f"\nIter param test for {iter_param_test[iterasi]} is complete")
    g_best_fitness.append(g_best_fitness_temp / 5)
    average_fitness.append(average_fitness_temp / 5)


fig, ax = plt.subplots()
ax.plot(iter_param_test, average_fitness, label="Average Fitness")
ax.plot(iter_param_test, g_best_fitness, label="Best Fitness")
ax.legend(loc="upper right")

ax.set(xlabel='iteration size (t)', ylabel='average fitness (accuracy)',
       title='Iteration Test')
ax.grid()

fig.savefig("result/iter_test.png")

plt.show()
# Out:
# . . . . .
# Iter param test for 20 is complete
# . . . . .
# Iter param test for 40 is complete
# . . . . .
# Iter param test for 60 is complete
# . . . . .
# Iter param test for 80 is complete

# %%
g_best_fitness = []
average_fitness = []

part_size_param_test = [5, 10, 15, 20]
for part_size in range(len(part_size_param_test)):
    g_best_fitness_temp = 0
    average_fitness_temp = 0
    for i in range(5):
        print('.',end=' ')
        pso_backpp = PSOxBackpro(part_size_param_test[part_size], 15, 1)
        pso_backpp.set_backpro_param(X_train, Y_train, X_test, Y_test, max_val, min_val, epoch=40)
        pso_backpp.initPops()
        gbest_fitness, avg_fitness = pso_backpp.optimize(25, 1, 1, 1)
        g_best_fitness_temp += gbest_fitness
        average_fitness_temp += avg_fitness
    print(f"\nParticle param test for {part_size_param_test[part_size]} is complete")
    g_best_fitness.append(g_best_fitness_temp / 5)
    average_fitness.append(average_fitness_temp / 5)


fig, ax = plt.subplots()
ax.plot(part_size_param_test, average_fitness, label="Average Fitness")
ax.plot(part_size_param_test, g_best_fitness, label="Best Fitness")
ax.legend(loc="upper right")

ax.set(xlabel='pop size (n)', ylabel='average fitness (accuracy)',
       title='PSOs Particle Pop Size Test')
ax.grid()

fig.savefig("result/par_pop_size_test.png")

plt.show()
# Out:
# . . . . .
# Particle param test for 5 is complete
# . . . . .
# Particle param test for 10 is complete
# . . . . .
# Particle param test for 15 is complete
# . . . . .
# Particle param test for 20 is complete

# %%
g_best_fitness = []
average_fitness = []

c_param_test = [(2.5, 0.5), (2, 1), (1.5, 1.5), (1, 2), (0.5, 2.5)]
param_test_str = []
for c in range(len(c_param_test)):
    g_best_fitness_temp = 0
    average_fitness_temp = 0
    param_test_str.append(c)
    for i in range(5):
        print('.',end=' ')
        pso_backpp = PSOxBackpro(40, 15, 1)
        pso_backpp.set_backpro_param(X_train, Y_train, X_test, Y_test, max_val, min_val, epoch=40)
        pso_backpp.initPops()
        gbest_fitness, avg_fitness = pso_backpp.optimize(25, 1, c_param_test[c][0], c_param_test[c][1])
        g_best_fitness_temp += gbest_fitness
        average_fitness_temp += avg_fitness
    print(f"\nc1 & c2 param test for {c_param_test[c]} is complete")
    g_best_fitness.append(g_best_fitness_temp / 5)
    average_fitness.append(average_fitness_temp / 5)


fig, ax = plt.subplots()
ax.plot(param_test_str, average_fitness, label="Average Fitness")
ax.plot(param_test_str, g_best_fitness, label="Best Fitness")
ax.legend(loc="upper right")

ax.set(xlabel='c1 & c2', ylabel='average fitness (accuracy)',
       title='PSOs Combination of c1 & c2 Value Test')
ax.grid()

fig.savefig("result/c_value_test.png")

plt.show()

# %%
g_best_fitness = []
average_fitness = []

w_param_test = [0.4, 0.5, 0.6]
for w in range(len(w_param_test)):
    g_best_fitness_temp = 0
    average_fitness_temp = 0
    for i in range(5):
        print('.',end=' ')
        pso_backpp = PSOxBackpro(40, 15, 1)
        pso_backpp.set_backpro_param(X_train, Y_train, X_test, Y_test, max_val, min_val, epoch=40)
        pso_backpp.initPops()
        gbest_fitness, avg_fitness = pso_backpp.optimize(25, w_param_test[w], 2.5, 0.5)
        g_best_fitness_temp += gbest_fitness
        average_fitness_temp += avg_fitness
    print(f"\nw param test for {w_param_test[w]} is complete")
    g_best_fitness.append(g_best_fitness_temp / 5)
    average_fitness.append(average_fitness_temp / 5)


fig, ax = plt.subplots()
ax.plot(w_param_test, average_fitness, label="Average Fitness")
ax.plot(w_param_test, g_best_fitness, label="Best Fitness")
ax.legend(loc="upper right")

ax.set(xlabel='w', ylabel='average fitness (accuracy)',
       title='PSOs w Value Test')
ax.grid()

fig.savefig("result/w_value_test.png")

plt.show()

# %%
g_best_fitness = []
average_fitness = []

k_param_test = [0.2, 0.4, 0.6]
for k in range(len(k_param_test)):
    g_best_fitness_temp = 0
    average_fitness_temp = 0
    for i in range(5):
        print('.',end=' ')
        pso_backpp = PSOxBackpro(40, 15, k_param_test[k])
        pso_backpp.set_backpro_param(X_train, Y_train, X_test, Y_test, max_val, min_val, epoch=40)
        pso_backpp.initPops()
        gbest_fitness, avg_fitness = pso_backpp.optimize(25, 0.4, 2.5, 0.5)
        g_best_fitness_temp += gbest_fitness
        average_fitness_temp += avg_fitness
    print(f"\nk param test for {k_param_test[k]} is complete")
    g_best_fitness.append(g_best_fitness_temp / 5)
    average_fitness.append(average_fitness_temp / 5)


fig, ax = plt.subplots()
ax.plot(k_param_test, average_fitness, label="Average Fitness")
ax.plot(k_param_test, g_best_fitness, label="Best Fitness")
ax.legend(loc="upper right")

ax.set(xlabel='k', ylabel='average fitness (accuracy)',
       title='PSOs k-Velocity Clamping Value Test')
ax.grid()

fig.savefig("result/k_value_test.png")
plt.show()
